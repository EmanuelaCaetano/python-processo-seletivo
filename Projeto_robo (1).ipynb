# %% [markdown]
# Participantes:
#
# Emanuela Aparecida Gonçalves Caetano
#
# Kayky Arthur Silva dos Santos
#
# Weslley  Carlos Holanda

# %%
robot_art = r"""
      0: {head_name}
      Is available: {head_status}
      Attack: {head_attack}                              
      Defense: {head_defense}
      Energy consumption: {head_energy_consump}
              ^
              |                  |1: {weapon_name}
              |                  |Is available: {weapon_status}
     ____     |    ____          |Attack: {weapon_attack}
    |oooo|  ____  |oooo| ------> |Defense: {weapon_defense}
    |oooo| '    ' |oooo|         |Energy consumption: {weapon_energy_consump}
    |oooo|/\_||_/\|oooo|          
    `----' / __ \  `----'           |2: {left_arm_name}
   '/  |#|/\/__\/\|#|  \'           |Is available: {left_arm_status}
   /  \|#|| |/\| ||#|/  \           |Attack: {left_arm_attack}
  / \_/|_|| |/\| ||_|\_/ \          |Defense: {left_arm_defense}
 |_\/    O\=----=/O    \/_|         |Energy consumption: {left_arm_energy_consump}
 <_>      |=\__/=|      <_> ------> |
 <_>      |------|      <_>         |3: {right_arm_name}
 | |   ___|======|___   | |         |Is available: {right_arm_status}
// \\ / |O|======|O| \  //\\        |Attack: {right_arm_attack}
|  |  | |O+------+O| |  |  |        |Defense: {right_arm_defense}
|\/|  \_+/        \+_/  |\/|        |Energy consumption: {right_arm_energy_consump}
\__/  _|||        |||_  \__/        
      | ||        || |          |4: {left_leg_name} 
     [==|]        [|==]         |Is available: {left_leg_status}
     [===]        [===]         |Attack: {left_leg_attack}
      >_<          >_<          |Defense: {left_leg_defense}
     || ||        || ||         |Energy consumption: {left_leg_energy_consump}
     || ||        || || ------> |
     || ||        || ||         |5: {right_leg_name}
   __|\_/|__    __|\_/|__       |Is available: {right_leg_status}
  /___n_n___\  /___n_n___\      |Attack: {right_leg_attack}
                                |Defense: {right_leg_defense}
                                |Energy consumption: {right_leg_energy_consump}
                                
"""

colors = { #alteração das letras PARA TUDO MAIUSCULO
        "BLACK": '\x1b[90m',
        "BLUE": '\x1b[94m\x1b[38;5;4m', #alteração do tom para maior contraste no tema preto
        "CYAN": '\x1b[96m',
        "GREEN": '\x1b[92m',
        "MAGENTA": '\x1b[95m',
        "RED": '\x1b[91m',
        "WHITE": '\x1b[38;5;230m', #alteração do tom para a vizualização em tema claro 
        "YELLOW":'\x1b[93m',
    }

class Part():
    
    def __init__(self, name: str, attack_level=0, defense_level=0, energy_consumption=0):
        self.name = name
        self.attack_level = attack_level
        self.defense_level = defense_level
        self.energy_consumption = energy_consumption
        
    def get_status_dict(self):
        formatted_name = self.name.replace(" ", "_").lower()
        return {
            "{}_name".format(formatted_name): self.name.upper(),
            "{}_status".format(formatted_name): self.is_available(),
            "{}_attack".format(formatted_name): self.attack_level,
            "{}_defense".format(formatted_name): self.defense_level,
            "{}_energy_consump".format(formatted_name): self.energy_consumption,
        }
        
    def reduce_edefense(self, attack_level):
        self.defense_level = self.defense_level - attack_level
        if self.defense_level <= 0:
            self.defense_level = 0

    def is_available(self):
        return self.defense_level > 0 #alteração para  que quando o robo se esgote a energia termine a partida(qunado todas as peças chegam a 0 o jogo finaliza)

class Robot:
    def __init__(self, name, color_code):
        self.name = name
        self.color_code = color_code
        self.energy = 100
        self.parts = [
            Part("Head", attack_level=5, defense_level=10, energy_consumption=5),
            Part("Weapon", attack_level=15, defense_level=0, energy_consumption=10),
            Part("Left Arm", attack_level=3, defense_level=20, energy_consumption=10),
            Part("Right Arm", attack_level=6, defense_level=20, energy_consumption=10),
            Part("Left Leg", attack_level=4, defense_level=20, energy_consumption=15),
            Part("Right Leg", attack_level=8, defense_level=20, energy_consumption=15),
        ]
    

    def print_status(self):
        print(self.color_code)
        str_robot = robot_art.format(**self.get_part_status())
        self.greet()
        self.print_energy()
        print(str_robot)
        print(colors["RED"]) #troca para funcionar tanto no modo claro quanto para o escuro
    

    def greet(self):
        print("Hello, my name is", self.name)
    

    def print_energy(self):
        print("We have", self.energy, " percent energy left")
    
    def get_part_status(self):
        part_status = {}
        for part in self.parts:
            status_dict = part.get_status_dict()
            part_status.update(status_dict)
        return part_status
        
    def attack(self, enemy_robot, part_to_use, part_to_attack):
        enemy_robot.parts[part_to_attack].reduce_edefense(self.parts[part_to_use].attack_level) 
        self.energy -= self.parts[part_to_use].energy_consumption

    def is_there_available_part(self):
        for part in self.parts:
            if part.is_available(): 
                return True
        return False
    

    def is_on(self):
        return self.energy > 0 #para que a energia não fique negativa

      
        
def build_robot():
    robot_name = input("Robot name: ")
    color_code = choose_color()
    robot = Robot(robot_name, color_code)
    robot.print_status()
    return robot


used_colors = [] #criação de array vazio para auxiliar na proxima função

def choose_color():
    available_colors = colors.copy() #criação de uma copia do dicionario colors para não haver repetição de cores nem erro no codigo caso seja inserido um valor errado
    for x in used_colors: # percorre o array
        if x in available_colors: #verifica
            del available_colors[x] # deleta

    print("Available colors:")
    for key, value in available_colors.items():
        print(value, key)

    chosen_color = input("Choose a color: ").upper() #passagem para maiusculo
    while chosen_color not in available_colors:  #condição caso digite errado
        chosen_color = input("This color is not available, please choose a color again: ").upper()

    used_colors.append(chosen_color)
    color_code = available_colors[chosen_color]

    return color_code



def play():
    playing = True
    print("Welcome to the game!")
    print("Datas for player 1:")
    robot_one = build_robot()
    print("Datas for player 2:")
    robot_two = build_robot()
    
    current_robot = robot_one
    enemy_robot = robot_two
    rount = 0
    
    while playing:
        if rount % 2 == 0:
            current_robot = robot_one
            enemy_robot = robot_two
        else:
            current_robot = robot_two
            enemy_robot = robot_one
        current_robot.print_status()
        print("What part should I use to attack?:")
        part_to_use = input("Choose a number part: ")
        part_to_use = int(part_to_use)
        while  part_to_use < 0 or part_to_use > 5: #adição de condição para quando o usuario inserir uma entrada de ataque errada
          part_to_use = input("This number is not available, please Choose a enemy number part to use again: ")
          part_to_use = int(part_to_use) 
        else:
        
          enemy_robot.print_status()
          print("Which part of the enemy should we attack?")
          part_to_attack = input("Choose a enemy number part to attack: ")
          part_to_attack = int(part_to_attack)
          while part_to_attack < 0 or part_to_attack >5:  #adição de condição para quando o usuario inserir uma entrada de ataque errada
            part_to_attack = input("This number is not available, please Choose a enemy number part to attack again: ")
            part_to_attack = int(part_to_attack)
          else:
            current_robot.attack(enemy_robot, part_to_use, part_to_attack)
            rount += 1

        print("you used a part: {} to attack and spent {} energy".format(part_to_use, current_robot.parts[part_to_use].energy_consumption)) #auxilio npara acompanhar a dinamica do jogo

        if not enemy_robot.is_on() or enemy_robot.is_there_available_part() == False:
            playing = False
            print("Congratulations, player one you won. Robot: {}".format(robot_one.name)) #adição do nome do robo vencedor
        if not current_robot.is_on() or current_robot.is_there_available_part() == False:
            playing = False
            print("Congratulations, player two won. Robot: {}".format(robot_two.name))
play()
# Out:
# Welcome to the game!
# Datas for player 1:
# Robot name: manu
# Available colors:
#  BLACK
#  BLUE
#  CYAN
#  GREEN
#  MAGENTA
#  RED
#  WHITE
#  YELLOW
# Choose a color: magenyta
# This color is not available, please choose a color again: magenta
#
# Hello, my name is manu
# We have 100  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
#
# Datas for player 2:
# Robot name: carlos
# Available colors:
#  BLACK
#  BLUE
#  CYAN
#  GREEN
#  RED
#  WHITE
#  YELLOW
# Choose a color: blue
#
# Hello, my name is carlos
# We have 100  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
#
#
# Hello, my name is manu
# We have 100  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
#
# What part should I use to attack?:
# Choose a number part: 5
#
# Hello, my name is carlos
# We have 100  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 2
# you used a part: 5 to attack and spent 15 energy
#
# Hello, my name is carlos
# We have 100  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 12
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
#
# What part should I use to attack?:
# Choose a number part: 1
#
# Hello, my name is manu
# We have 85  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 3
# you used a part: 1 to attack and spent 10 energy
#
# Hello, my name is manu
# We have 85  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 5
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
#
# What part should I use to attack?:
# Choose a number part: 7
# This number is not available, please Choose a enemy number part to use again: 3
#
# Hello, my name is carlos
# We have 90  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 12
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 4
# you used a part: 3 to attack and spent 10 energy
#
# Hello, my name is carlos
# We have 90  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 12
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 14
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
#
# What part should I use to attack?:
# Choose a number part: 5
#
# Hello, my name is manu
# We have 75  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 5
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 1
# you used a part: 5 to attack and spent 15 energy
#
# Hello, my name is manu
# We have 75  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 5
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
#
# What part should I use to attack?:
# Choose a number part: 3
#
# Hello, my name is carlos
# We have 75  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 12
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 14
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 2
# you used a part: 3 to attack and spent 10 energy
#
# Hello, my name is carlos
# We have 75  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 6
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 14
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
#
# What part should I use to attack?:
# Choose a number part: 5
#
# Hello, my name is manu
# We have 65  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 5
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 1
# you used a part: 5 to attack and spent 15 energy
#
# Hello, my name is manu
# We have 65  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 5
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
#
# What part should I use to attack?:
# Choose a number part: 3
#
# Hello, my name is carlos
# We have 60  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 6
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 14
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 5
# you used a part: 3 to attack and spent 10 energy
#
# Hello, my name is carlos
# We have 60  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 6
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 14
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 14
#                                 |Energy consumption: 15
#
#
#
# What part should I use to attack?:
# Choose a number part: 1
#
# Hello, my name is manu
# We have 55  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 5
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 5
# you used a part: 1 to attack and spent 10 energy
#
# Hello, my name is manu
# We have 55  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 5
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 5
#                                 |Energy consumption: 15
#
#
#
# What part should I use to attack?:
# Choose a number part: 1
#
# Hello, my name is carlos
# We have 50  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 6
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 14
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 14
#                                 |Energy consumption: 15
#
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 5
# you used a part: 1 to attack and spent 10 energy
#
# Hello, my name is carlos
# We have 50  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 6
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 14
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
#
# What part should I use to attack?:
# Choose a number part: 2
#
# Hello, my name is manu
# We have 45  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 5
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 5
#                                 |Energy consumption: 15
#
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 3
# you used a part: 2 to attack and spent 10 energy
#
# Hello, my name is manu
# We have 45  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 2
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 5
#                                 |Energy consumption: 15
#
#
#
# What part should I use to attack?:
# Choose a number part: 1
#
# Hello, my name is carlos
# We have 40  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 6
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 14
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 5
# you used a part: 1 to attack and spent 10 energy
#
# Hello, my name is carlos
# We have 40  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 6
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 14
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
#
# What part should I use to attack?:
# Choose a number part: 1
#
# Hello, my name is manu
# We have 35  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 2
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 5
#                                 |Energy consumption: 15
#
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 5
# you used a part: 1 to attack and spent 10 energy
#
# Hello, my name is manu
# We have 35  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 2
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
#
# What part should I use to attack?:
# Choose a number part: 1
#
# Hello, my name is carlos
# We have 30  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 6
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# ...
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
#
# What part should I use to attack?:
# Choose a number part: 1
#
# Hello, my name is manu
# We have 25  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 2
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 5
# you used a part: 1 to attack and spent 10 energy
#
# Hello, my name is manu
# We have 25  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 2
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
#
# What part should I use to attack?:
# Choose a number part: 1
#
# Hello, my name is carlos
# We have 20  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 6
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 14
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 5
# you used a part: 1 to attack and spent 10 energy
#
# Hello, my name is carlos
# We have 20  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 6
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 14
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
#
# What part should I use to attack?:
# Choose a number part: 2
#
# Hello, my name is manu
# We have 15  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 2
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 5
# you used a part: 2 to attack and spent 10 energy
#
# Hello, my name is manu
# We have 15  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 2
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
#
# What part should I use to attack?:
# Choose a number part: 3
#
# Hello, my name is carlos
# We have 10  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 6
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 14
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 5
# you used a part: 3 to attack and spent 10 energy
#
# Hello, my name is carlos
# We have 10  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 6
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 14
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
#
# What part should I use to attack?:
# Choose a number part: 2
#
# Hello, my name is manu
# We have 5  percent energy left
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 2
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: False
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 0
#                                 |Energy consumption: 15
#
#
#
# Which part of the enemy should we attack?
# Choose a enemy number part to attack: 5
# you used a part: 2 to attack and spent 10 energy
# Congratulations, player two won. Robot: carlos
